# %%
# Import the libraries
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
model_evaluation = pd.DataFrame(columns=['Dataset','ModelType','Metrix','Score'])
for i in range(1,6):
    train_name = 'Bike_Train0'+str(i)+'.csv'
    test_name = 'Bike_Test0'+str(i)+'.csv'
    dataset_train = pd.read_csv("/home/tintin/Study/Data-science/Statistical-machine-learning/Learn-multiple-linear-regression/Datasets/%s" %train_name)
    dataset_test = pd.read_csv("/home/tintin/Study/Data-science/Statistical-machine-learning/Learn-multiple-linear-regression//Datasets/%s" %test_name)
    dataset_train = dataset_train.drop(columns=['hum'])
    dataset_test = dataset_test.drop(columns=['hum'])
    
    X_train = dataset_train.iloc[:,9:12].values
    Y_train = dataset_train.iloc[:,-1].values
    
    X_test = dataset_test.iloc[:,9:12].values
    Y_test = dataset_test.iloc[:,-1].values
    
    lin_reg = LinearRegression()
    lin_reg.fit(X_train,Y_train)
    
    Y_test_pred = lin_reg.predict(X_test)
    Y_train_pred = lin_reg.predict(X_train)
    
    model_evaluation = model_evaluation.append({'Dataset': i, 
                                                'ModelType': 'MultipleLinear', 
                                                'Metrix': 'R2',
                                                'Score': r2_score(Y_test, Y_test_pred)}, 
                                               ignore_index=True)
    model_evaluation = model_evaluation.append({'Dataset': i, 
                                                'ModelType': 'MultipleLinear', 
                                                'Metrix': 'RMSE',
                                                'Score': sqrt(mean_squared_error(Y_test, Y_test_pred))}, 
                                               ignore_index=True)

# %%
model_evaluation
# Out:
#   Dataset       ModelType Metrix        Score
# 0       1  MultipleLinear     R2    -1.030459
# 1       1  MultipleLinear   RMSE  1805.220449
# 2       2  MultipleLinear     R2    -1.030459
# 3       2  MultipleLinear   RMSE  1805.220449
# 4       3  MultipleLinear     R2    -7.448884
# 5       3  MultipleLinear   RMSE  2337.641269
# 6       4  MultipleLinear     R2     0.265928
# 7       4  MultipleLinear   RMSE   841.017947
# 8       5  MultipleLinear     R2    -1.418354
# 9       5  MultipleLinear   RMSE  1718.603307
